# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
def getConn():
    conn =  pymysql.connect(host = '123.60.11.177', #123.60.8.234
                                user = 'root',
                                password = 'ncu@jw114', #123456
                                database = 'examArrange1',
                                charset = 'utf8mb4',
                                cursorclass = pymysql.cursors.DictCursor)
    return conn

def getDF(sql):           # 'mysql+pymysql://root:123456@123.60.8.234:3306/examArrange1'
    engin = create_engine('mysql+pymysql://root:ncu@jw114@123.60.11.177:3306/examArrange1')
    df = pd.read_sql_query(sql, engin)
    return df

# %%
sql_teacher_inf = "select tei_no,tei_name, tei_units from teacher_inf" # 教师信息
sql_teacher_state = "select tei_no, tei_units, mti_no, tei_state from dm_teacher_state" # 教师监考可用状态
sql_classroom_inf = "select cr_name, cr_special, cr_testseat from classroom_inf" # 教室信息
sql_class_inf = "select ci_course_no, ci_teacher_name, ci_class_name, ci_student_number, ci_appoint, ci_class_dep from classs_inf where ci_exam_type = '笔试考试' \
and ci_class_sign = 1 and ci_student_number != 0 order by ci_course_no limit 0,1000"
sql_classroom_state = "select cr_name, mti_no, cr_state from dm_classroom_state"
sql_end_testinfo = "SELECT eti_id,mti_id, ci_course_no, di_no, eti_class_name, eti_student_number, cr_no FROM end_testinfo"

# %%
df_sql_teacher_inf = getDF(sql_teacher_inf)
df_sql_teacher_state = getDF(sql_teacher_state)
df_sql_classroom_inf = getDF(sql_classroom_inf)
df_sql_classroom_state = getDF(sql_classroom_state)
df_sql_class_inf = getDF(sql_class_inf)
df_sql_end_testinfo = getDF(sql_end_testinfo)
df_end_res = pd.concat([df_sql_class_inf,pd.DataFrame(columns=['mti_no']),pd.DataFrame(columns=['cr_name'])]) # 结果表

# %%
df_sql_class_inf = getDF(sql_class_inf)

# %%
df_end_res = pd.concat([df_sql_class_inf,pd.DataFrame(columns=['mti_no']),pd.DataFrame(columns=['cr_name'])])
#df_sql_class_inf.insert(df_sql_class_inf.shape[1],'mti_no',0)
df_end_res['end_no'] = range(len(df_end_res))

# %%
sql_classroom_inf_state = "SELECT a.cr_name, a.cr_special, a.cr_testseat, b.mti_no, b.cr_state \
FROM classroom_inf a INNER JOIN dm_classroom_state b ON a.cr_name = b.cr_name WHERE 1=1"
sql_classroom_inf_state = getDF(sql_classroom_inf_state)

# %%
sql_mid_testinfo = "select * from mid_testinfo"
df_sql_mid_testinfo = getDF(sql_mid_testinfo)

# %%
for i in df_end_res.to_numpy():
    print(i[6])
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# ...

# %%
df_end_res.head()
# Out:
#   ci_course_no ci_teacher_name                              ci_class_name  \
# 0     101CL001             万淑辉                             计算机Ⅱ类[2011-5]班
# 1     101CL001             刘辉良                   计算机Ⅱ类[206-9]班,计算机Ⅱ类2010班
# 2     101CL001              黄安                              计算机Ⅱ类[201-5]班
# 3     101CL001              杨慧             过程装备与控制工程201班,环境科学与工程类[201-3]班
# 4     101CL001              曾艳  过程装备与控制工程202班,环境科学与工程类[204-5]班,化工与制药类202班
#
#    ci_student_number  ci_appoint ci_class_dep mti_no cr_name  end_no
# 0              171.0         0.0         软件学院    NaN     NaN       0
# 1              170.0         0.0         软件学院    NaN     NaN       1
# 2              174.0         0.0         软件学院    NaN     NaN       2
# 3              127.0         0.0        公共课排课    NaN     NaN       3
# 4              124.0         0.0        公共课排课    NaN     NaN       4

# %%
df_end_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ci_course_no       1000 non-null   object
#  1   ci_teacher_name    1000 non-null   object
#  2   ci_class_name      1000 non-null   object
#  3   ci_student_number  1000 non-null   float64
#  4   ci_appoint         1000 non-null   float64
#  5   ci_class_dep       1000 non-null   object
#  6   mti_no             0 non-null      object
#  7   cr_name            0 non-null      object
#  8   end_no             1000 non-null   int32
# dtypes: float64(2), int32(1), object(6)
# memory usage: 74.2+ KB

# %%
'计算机Ⅱ类[201-5]班' in df_end_res["ci_class_name"].tolist()
# Out:
# True

# %%
Array_df_end_res = df_end_res.to_numpy()
class_name_list = []

for inx, val in enumerate(Array_df_end_res):
    class_name_list.extend(val[2].split(","))
    
class_name_list = list(dict.fromkeys(class_name_list))

sql_1 = ""

# %%
ser = pd.Series(class_name_list)

# %%
ser.to_csv('class_name_list.csv')

# %%
Array_df_end_res = df_end_res.to_numpy()
class_name_list = []
class_name_list.extend(Array_df_end_res[1][2].split(","))
class_name_list.extend(Array_df_end_res[3][2].split(","))
class_name_list
# Out:
# ['计算机Ⅱ类[206-9]班', '计算机Ⅱ类2010班', '过程装备与控制工程201班', '环境科学与工程类[201-3]班']

# %%
Array_sql_class_inf_1 = df_sql_class_inf.to_numpy()
Array_sql_class_inf_2 = df_sql_class_inf.to_numpy()

course_list = []
teacher_list = []
class_name_list = []
stu_count_list = []
for inx, val in enumerate(Array_sql_class_inf_1):
    course = val[0]
    teacher = val[1]
    class_name = val[2]
    stu_count = val[3]
    if course = val[0]:
        course_list.append(course)
        teacher_list.append(teacher.split(":"))
        class_name_list.append(class_name.split(","))
        stu_count_list.append(stu_count)
# Out:
# 杨彦军
#
# 张欣
#
#
# 吕合
# 赵瑄
# 曾祥太
# 吕志涛
# 支清
# 赵抚民
# 刘伟平
# 刘小文
# 黄紫筠:乐建辉
# 刘剑凌
# 陈文财
# 王三华
# 戴小花
# 尹秀霞
# 周理凤
# 王丽坤:左烨
# 李鸿艳:李玲艳:周湖燕
# 刘卓琦
# 刘卓琦
# 敖建云:蔡霞:丁颖:樊有龙:房向东:胡晓彦:黄天伦:宋渊:王三怡:徐承云:徐臻:占徐龙:章海斌:张润香
# 闰彩霞
# 何朝珠:刘宇
# 贾书磊:刘萌:刘宇:张晓飞:周湖燕
# 黄菊花
# 谭刚平
# 曹铭:肖先锋
# 杨雪春:张超华
# 曹铭
# 吴晓建
# 陈宗渝
# 付艳恕:赵朋龙
# 吴晓建
# 张庭芳
# 赵伊濛
# 周璇
# 蒋三三
# 曾洁
# 吴光芸
# 吴光芸
# 李艾丽莎
# 王绚
# 谢永飞
# 王海英
# 贾清萍
# 刘海涛
# 刘海涛
# 罗亮
# 陈美华
# 陈美华
# 张逸云
#
#
# 徐丹
#
#
#
#
#
# 常以力:刘艳:万生辉:熊芬:袁林
# 林娜娜:刘艳:万生辉
# 罗云峰:张凤俊:邹琼
# 石增
# 余虹
# 卢苇
# 高美才
# 刘金菊
#
# 张芳
# 董秋仙
# 范志平
# 周雪珍
# 范志平
# 范志平
# 王英俊
# 周雪珍
# 王英俊
# 何薇
# 龙婷:秦子顺:王晓雪:羊晓
# 钞雪林:陈建云:李梦倩:孙茜:万爱兰
# 胡飞虎:李冠华:卢和丽:王碧漪:徐茜
# 方鑫:李小兵:刘怡:熊英琼:赵斐:周益毅
# 程峙娟:甘莉:唐震宇:涂江龙:吴伟:谢亮:殷敏
# 曹春水:蒋蒙蒙:王昊:熊强强:叶伟
# 曹戍:高维寅:李金:廖春耀:刘远飞:柳远飞:王义兵:吴利东
# 陈启文:陈晓:黄涛:李德元:孙梦思:孙萍:吴冬科:吴俭:武志红:袁高乐
# 曹晓春:李国林:罗景华
# 蔡丽萍:陈新萍:陈琦:江如:李昳颖:刘福军:陶利民:涂春华:徐小霞:杨丽兰:尹春华:张乡城:张智
# 丰颖:贺晓菊:刘雯婷:谭布珍:童焰:姚美珍:张玮:赵璐
# 邓小荣:胡小云:江伟凡:金彦召:雷钧:李红浪:梁博:梁辉:刘洪亮:魏益平:吴淼经:虞黎明:余磊涛:袁春雷:张文雄:周建良:周为民:朱仙花:朱正明:宗振
# 艾教育:蔡芬:陈传辉:胡小亮:康婷:李建蓉:刘建英:卢玮:聂俊刚:潘晓林:齐凌:宋兵:汤佳珍:王缨:吴友平:徐积兄:应国秋:占小江:赵田甜:朱建兵
# ...

# %%
series_course = df_end_res.drop(['ci_teacher_name','ci_class_name','ci_student_number','ci_appoint','mti_no',
                                 'cr_name','ci_class_dep'],axis=1).drop_duplicates(['ci_course_no']) # 待排课程号
tmp_end_no = series_course['end_no'].to_numpy() # 待排课程号
Array_series_course = series_course.to_numpy() # ?
#Array_sql_classroom_inf = df_sql_classroom_inf.to_numpy() # 教室信息表
#Array_sql_classroom_state = df_sql_classroom_state.to_numpy() # 教室状态表
Array_sql_classroom_inf_state = sql_classroom_inf_state.to_numpy() 
Array_sql_mid_testinf = df_sql_mid_testinfo.to_numpy()

# %%
Array_sql_classroom_inf_state
# Out:
# array([['慧源楼101', '否', 80, 1, 1],
#        ['慧源楼101', '否', 80, 2, 1],
#        ['慧源楼101', '否', 80, 3, 1],
#        ...,
#        ['虚拟教室01', '否', 2000, 22, 1],
#        ['虚拟教室01', '否', 2000, 23, 1],
#        ['虚拟教室01', '否', 2000, 24, 1]], dtype=object)

# %%
Array_sql_class_inf_1
# Out:
# array([['710ZP005', '郭曦', '公共管理类[201-2]班', 72, 0, '公管学院'],
#        ['710ZP005', '郭曦', '公共管理类[203-4]班', 74, 0, '公管学院'],
#        ['710ZP005', '张新生', '公共管理类205班', 36, 0, '公管学院'],
#        ['710ZP005', '潘云华', '人力资源管理（第二学士学位）201班,行政管理（第二学士学位）201班', 76, 0,
#         '公管学院'],
#        ['710ZP007', '齐小兵', '公共关系学201班', 28, 0, '公管学院']], dtype=object)

# %%
import numpy as np 
df_end_res.iloc[0 : 33,6] = np.nan
#print(str(Array_sql_mid_testinf[3][0]))
#df_end_res.iloc[0 : 33,6] = str(Array_sql_mid_testinf[3][0])

# %%
end_no_0 = tmp_end_no[0]
end_no_1 = tmp_end_no[1]
end_sum = df_sql_class_inf.shape[0] # 总开课表行数
tmp_end_no = series_course['end_no'].to_numpy() # 开课表索引

i_len = series_course.shape[0] - 2

for i in range(i_len):
    Array_sql_class_inf_1 = df_sql_class_inf.iloc[end_no_0 : end_no_1 + 1].to_numpy()
    if i < i_len:
        end_no_0,end_no_1 = end_no_1,tmp_end_no[i + 2]
    else:
        end_no_0,end_no_1 = end_no_1,end_sum
    for inx_1, val_1 in enumerate(Array_sql_mid_testinf):
        flag = 0
        for inx_2, val_2 in enumerate(Array_sql_class_inf_1):
            if str(df_end_res[(df_end_res.ci_class_name == val_2[2])]["mti_no"].item) != 'nan':# 判断选中班级是否在当前时段有考试
                #print("chongfu_________")
                flag = 1
                break
            else:
                flag = 0
        if flag == 0:
            print(str(val_1[0]))
            df_end_res.iloc[end_no_0 : end_no_1 + 1,6] = str(val_1[0])

# %%
print(0b11111111111)
# Out:
# 2047

# %%
np.random.rand(10) * 1000 - 500
# Out:
# array([ 462.6534861 , -291.62216622,  -62.54625689,  347.47673581,
#         202.64838142, -103.75385597,  120.335399  , -326.34817708,
#         263.50157005, -335.85867167])

# %%
end_no_0 = tmp_end_no[0]
end_no_1 = tmp_end_no[1]
end_sum = df_sql_class_inf.shape[0] # 总开课表行数
tmp_end_no = series_course['end_no'].to_numpy() # 开课表索引

i_len = series_course.shape[0] - 2

for i in range(i_len):
    Array_sql_class_inf_1 = df_sql_class_inf.iloc[end_no_0 : end_no_1 + 1].to_numpy()
    if i < i_len:
        end_no_0,end_no_1 = end_no_1,tmp_end_no[i + 2]
    else:
        end_no_0,end_no_1 = end_no_1,end_sum
    for inx_1, val_1 in enumerate(Array_sql_mid_testinf):
        flag = 0
        for inx_2, val_2 in enumerate(Array_sql_class_inf_1):
            if df_end_res[(df_end_res.ci_class_name == '计算机Ⅱ类[2011-5]班')]["mti_no"]: # 判断选中班级是否在当前时段有考试
                flag = 1
                break
        if flag = 0:
            df_end_res.iloc[end_no_0 : end_no_1 + 1]["mti_no"] = val_1[0]
# Out:
# 0 ['101CL001' '万淑辉' '计算机Ⅱ类[2011-5]班' 171 0 '软件学院']
# 1 ['101CL001' '刘辉良' '计算机Ⅱ类[206-9]班,计算机Ⅱ类2010班' 170 0 '软件学院']
# 2 ['101CL001' '黄安' '计算机Ⅱ类[201-5]班' 174 0 '软件学院']
# 3 ['101CL001' '杨慧' '过程装备与控制工程201班,环境科学与工程类[201-3]班' 127 0 '公共课排课']
# 4 ['101CL001' '曾艳' '过程装备与控制工程202班,环境科学与工程类[204-5]班,化工与制药类202班' 124 0 '公共课排课']
# 5 ['101CL001' '胡慷' '化工与制药类201班,化工与制药类[201-4]班' 98 0 '公共课排课']
# 6 ['101CL001' '胡邦宁:吴丹' '人工智能201班,测控技术与仪器[201-2]班' 110 0 '公共课排课']
# 7 ['101CL001' '马文军' '自动化[201-4]班' 110 0 '公共课排课']
# 8 ['101CL001' '谭潭' '计算机Ⅰ类[204-6]班' 96 0 '公共课排课']
# 9 ['101CL001' '方娜:欧阳润' '计算机Ⅰ类[201-3]班' 96 0 '公共课排课']
# 10 ['101CL001' '罗荣萍' '电气工程及其自动化[201-3]班' 99 0 '公共课排课']
# 11 ['101CL001' '黄紫筠:乐建辉' '金融数学[201-2]班,前湖学院综合实验班201班' 96 0 '公共课排课']
# 12 ['101CL001' '石增' '材料类202班,材料类[202-7]班' 92 0 '公共课排课']
# 13 ['101CL001' '余虹' '材料类201班,材料类[201-5]班' 110 0 '公共课排课']
# 14 ['101CL001' '王美艳' '土木类[201-4]班' 115 0 '公共课排课']
# 15 ['101CL001' '吴斯亮' '土木类[205-8]班' 120 0 '公共课排课']
# ...

# %%
tmp_end_no = series_course['end_no'].to_numpy()
tmp_end_no[240]
# Out:
# 996

# %%
df_end_res["ci_class_name"].str.contains('计算机Ⅱ类[2011-5]班')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: ci_class_name, Length: 1000, dtype: bool

# %%
for index, row in df_sql_class_inf.iterrows():
    print(row['ci_course_no'])
# Out:
# J910KN2001
# Z9100B0003
# T5130F4001
# T5130F4001
# J604SG0024
# J910KN1001
# T7210P4006
# J9100G2003
# 501ZP202
# 501ZP102
# 501ZP103
# 501ZP202
# 501ZP102
# 501ZP103
# 501ZP202
# 501ZP501
# 501ZP102
# 501ZP103
# 610GJ001
# 104GT002
# 501ZP501
# 501ZP602
# 501ZX212
# 501ZX306
# 501ZX101
# 501ZX209
# 501ZX406
# 104GT002
# 610GJ001
# 501ZX706
# 720GS001
# 501ZP501
# 501ZP102
# 501ZP103
# 501ZP202
# 501ZX406
# 501ZP602
# 501ZX212
# 501ZX306
# 501ZX101
# 501ZX209
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0026
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0024
# Z810KB0020
# Z810KB0021
# Z8100B0078
# Z8100B0035
# Z8100B0071
# Z8100B0055
# Z8100B0070
# Z8100B0007
# Z8100B1028
# J81B0Y0111
# Z8100B0094
# Z8100B1206
# J81ASY0023
# J81ASY0022
# J81ASY0024
# J81A0Y0039
# J81A0Y0036
# J81A0Y0037
# J81A0Y0035
# J81A0Y0036
# J81A0Y0037
# J81A0Y0035
# ...

# %%
df_sql_class_inf.to_numpy()
# Out:
# array([['101CL001', '万淑辉', '计算机Ⅱ类[2011-5]班', 171, 0],
#        ['101CL001', '刘辉良', '计算机Ⅱ类[206-9]班,计算机Ⅱ类2010班', 170, 0],
#        ['101CL001', '黄安', '计算机Ⅱ类[201-5]班', 174, 0],
#        ...,
#        ['710ZP007', '黄佳鹏', '公共关系学202班', 30, 0],
#        ['710ZP303', '贺晓玲', '应用心理学[201-2]班', 67, 0],
#        ['710ZP303', '贺晓玲', '应用心理学（第二学士学位）201班', 27, 0]], dtype=object)

# %%
df_sql_end_testinfo.head()
# Out:
# Empty DataFrame
# Columns: [eti_id, mti_id, ci_course_no, di_no, eti_class_name, eti_student_number, cr_no]
# Index: []

# %%
df_sql_classroom_inf['cr_testseat'].agg(sum)
# Out:
# 6078

# %%
df_sql_class_inf.head(20)
# Out:
#    ci_course_no ci_teacher_name                              ci_class_name  \
# 0      101CL001             万淑辉                             计算机Ⅱ类[2011-5]班
# 1      101CL001             刘辉良                   计算机Ⅱ类[206-9]班,计算机Ⅱ类2010班
# 2      101CL001              黄安                              计算机Ⅱ类[201-5]班
# 3      101CL001              杨慧             过程装备与控制工程201班,环境科学与工程类[201-3]班
# 4      101CL001              曾艳  过程装备与控制工程202班,环境科学与工程类[204-5]班,化工与制药类202班
# 5      101CL001              胡慷                  化工与制药类201班,化工与制药类[201-4]班
# 6      101CL001          胡邦宁:吴丹                   人工智能201班,测控技术与仪器[201-2]班
# 7      101CL001             马文军                                自动化[201-4]班
# 8      101CL001              谭潭                              计算机Ⅰ类[204-6]班
# 9      101CL001          方娜:欧阳润                              计算机Ⅰ类[201-3]班
# 10     101CL001             罗荣萍                          电气工程及其自动化[201-3]班
# ...

# %%
teacher_list = []
teacher_list.append(Array_sql_class_inf_1[0][1].split(":"))
teacher_list.append(Array_sql_class_inf_1[9][1].split(":"))
teacher_list
#Array_sql_class_inf_1[6][1].split(":")
# Out:
# [['万淑辉'], ['方娜', '欧阳润']]

# %%
for inx, val in enumerate(Array_sql_class_inf_1):
    print(inx,val)
# Out:
# 0 ['101CL001' '万淑辉' '计算机Ⅱ类[2011-5]班' 171 0]
# 1 ['101CL001' '刘辉良' '计算机Ⅱ类[206-9]班,计算机Ⅱ类2010班' 170 0]
# 2 ['101CL001' '黄安' '计算机Ⅱ类[201-5]班' 174 0]
# 3 ['101CL001' '杨慧' '过程装备与控制工程201班,环境科学与工程类[201-3]班' 127 0]
# 4 ['101CL001' '曾艳' '过程装备与控制工程202班,环境科学与工程类[204-5]班,化工与制药类202班' 124 0]
# 5 ['101CL001' '胡慷' '化工与制药类201班,化工与制药类[201-4]班' 98 0]
# 6 ['101CL001' '胡邦宁:吴丹' '人工智能201班,测控技术与仪器[201-2]班' 110 0]
# 7 ['101CL001' '马文军' '自动化[201-4]班' 110 0]
# 8 ['101CL001' '谭潭' '计算机Ⅰ类[204-6]班' 96 0]
# 9 ['101CL001' '方娜:欧阳润' '计算机Ⅰ类[201-3]班' 96 0]
# 10 ['101CL001' '罗荣萍' '电气工程及其自动化[201-3]班' 99 0]
# 11 ['101CL001' '黄紫筠:乐建辉' '金融数学[201-2]班,前湖学院综合实验班201班' 96 0]
# 12 ['101CL001' '石增' '材料类202班,材料类[202-7]班' 92 0]
# 13 ['101CL001' '余虹' '材料类201班,材料类[201-5]班' 110 0]
# 14 ['101CL001' '王美艳' '土木类[201-4]班' 115 0]
# 15 ['101CL001' '吴斯亮' '土木类[205-8]班' 120 0]
# 16 ['101CL001' '高杰' '化学类[203-5]班' 78 0]
# 17 ['101CL001' '陈宁' '化学类[201-2]班' 53 0]
# 18 ['101CL001' '邓志辉' '食品科学与工程类[201-3]班,生物工程201班' 120 0]
# ...
